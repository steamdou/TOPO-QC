# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.patches import FancyArrowPatch

pz = [0, 0.01, 0.02, 0.03, 0.04]
heralded = [0.17898793, 0.16580725, 0.15924147, 0.14150052, 0.112518356] #[0.178, 0.166, 0.154, 0.141, 0.113]
unheralded = [0.1611058, 0.160945756, 0.1594385, 0.15631992, 0.1498189] #[0.161, 0.154, 0.147, 0.139, 0.11]

plt.figure(figsize=(5, 4))
plt.plot(pz, heralded, marker='o', linestyle='-', label='ILP')
plt.plot(pz, unheralded, marker='s', linestyle='--', label='two-step MWPM')
plt.plot(0.04, 0.152, marker='o', linestyle='-', label='ILP-eff')
#0.13121459
# 0.106724045
#0.138

plt.xlabel(r'$p_z$')
plt.ylabel(r'$p_x$')
plt.legend(frameon=False)

plt.tight_layout()
plt.savefig("unstable.png", dpi=300, bbox_inches='tight')
plt.show()

# %%
(0.11775643-0.112518356)/0.112518356
# Out:
# 0.03282427980017773
