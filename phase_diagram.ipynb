# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.patches import FancyArrowPatch

pz = [0, 0.01, 0.02, 0.03, 0.04]
heralded = [0.1786388, 0.16556808, 0.15462427, 0.14164171, 0.11291497] #[0.178, 0.166, 0.154, 0.141, 0.113]
unheralded = [0.16150267, 0.15475368, 0.15944977, 0.15606333, 0.15002755]#[0.161, 0.154, 0.147, 0.139, 0.11]

plt.figure(figsize=(5, 4))

plt.plot(pz, heralded, marker='o', linestyle='-', label='ILP')
plt.plot(pz, unheralded, marker='s', linestyle='--', label='two-step MWPM')

plt.xlabel(r'$p_z$')
plt.ylabel(r'$p_x$')
plt.legend(frameon=False)

plt.tight_layout()
plt.savefig("unstable.png", dpi=300, bbox_inches='tight')
plt.show()
